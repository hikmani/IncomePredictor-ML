# %% [markdown]
# ## EDA

# %%
import pandas as pd
import numpy as np


path = '/content/test_final.csv'
df = pd.read_csv(path)

df.head()
# Out:
#    ID  age         workclass  fnlwgt     education  education.num  \
# 0   1   33  Self-emp-not-inc  222162       HS-grad              9
# 1   2   68                 ?   29240       HS-grad              9
# 2   3   34           Private  103596       HS-grad              9
# 3   4   57           Private  103403       5th-6th              3
# 4   5   48           Private  152915  Some-college             10
#
#        marital.status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse       Craft-repair        Husband  White    Male
# 1             Widowed                  ?  Not-in-family  White  Female
# 2  Married-civ-spouse  Handlers-cleaners        Husband  White    Male
# 3  Married-civ-spouse   Transport-moving        Husband  White    Male
# 4       Never-married       Adm-clerical  Not-in-family  White  Female
#
#    capital.gain  capital.loss  hours.per.week native.country
# 0             0             0              40  United-States
# 1             0             0              12  United-States
# 2             0             0              40  United-States
# 3             0             0              40  United-States
# 4             0             0              40  United-States

# %%
print(df.head())
# Out:
#    age         workclass  fnlwgt    education  education.num  \
# 0   53  Self-emp-not-inc   93449  Prof-school             15
# 1   33  Self-emp-not-inc  123424    Bachelors             13
# 2   47           Private  144844      HS-grad              9
# 3   40           Private  114580      HS-grad              9
# 4   39           Private  115618      HS-grad              9
#
#        marital.status        occupation    relationship                race  \
# 0  Married-civ-spouse    Prof-specialty         Husband  Asian-Pac-Islander
# 1  Married-civ-spouse   Exec-managerial         Husband               White
# 2  Married-civ-spouse      Craft-repair         Husband               White
# 3            Divorced      Craft-repair  Other-relative               White
# 4  Married-civ-spouse  Transport-moving         Husband               White
#
#       sex  capital.gain  capital.loss  hours.per.week native.country  \
# 0    Male             0             0              40          India
# 1    Male             0             0              40  United-States
# 2    Male             0             0              40  United-States
# 3  Female             0             0              40        Vietnam
# 4    Male             0             0              50  United-States
#
#    income>50K
# 0           1
# 1           1
# 2           0
# 3           0
# 4           0

# %%
print(df.shape)
# Out:
# (23842, 15)

# %%
print(df.dtypes)
# Out:
# ID                 int64
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# dtype: object

# %%
print(df.describe())
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  25000.000000  2.500000e+04   25000.000000  25000.000000  25000.000000
# mean      38.693480  1.887923e+05      10.074320   1110.614440     87.213840
# std       13.719406  1.058117e+05       2.576607   7555.089474    400.989282
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.171998e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.772995e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.356498e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week    income>50K
# count    25000.000000  25000.000000
# mean        40.527600      0.240640
# std         12.413688      0.427481
# min          1.000000      0.000000
# 25%         40.000000      0.000000
# 50%         40.000000      0.000000
# 75%         45.000000      0.000000
# max         99.000000      1.000000

# %%
missing_values = df.isin(['?']).sum()
print(missing_values)
# Out:
# age                  0
# workclass         1437
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1442
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     427
# income>50K           0
# dtype: int64

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(df[col].value_counts())
# Out:
# Private             16570
# Self-emp-not-inc     1884
# Local-gov            1519
# ?                    1362
# State-gov             944
# Self-emp-inc          850
# Federal-gov           702
# Without-pay             6
# Never-worked            5
# Name: workclass, dtype: int64
# HS-grad         7665
# Some-college    5307
# Bachelors       3981
# Masters         1288
# Assoc-voc       1006
# 11th             877
# Assoc-acdm       789
# 10th             700
# 7th-8th          464
# Prof-school      384
# 9th              371
# 12th             324
# Doctorate        287
# 5th-6th          249
# 1st-4th          111
# Preschool         39
# Name: education, dtype: int64
# Married-civ-spouse       10936
# Never-married             7891
# Divorced                  3221
# Separated                  801
# Widowed                    681
# Married-spouse-absent      302
# Married-AF-spouse           10
# Name: marital.status, dtype: int64
# Prof-specialty       2968
# Craft-repair         2967
# Exec-managerial      2914
# Adm-clerical         2784
# Sales                2777
# Other-service        2376
# Machine-op-inspct    1439
# ?                    1367
# Transport-moving     1163
# Handlers-cleaners    1025
# Farming-fishing       754
# Tech-support          703
# Protective-serv       477
# Priv-house-serv       123
# Armed-Forces            5
# Name: occupation, dtype: int64
# Husband           9605
# Not-in-family     6100
# Own-child         3702
# Unmarried         2490
# Wife              1169
# Other-relative     776
# Name: relationship, dtype: int64
# White                 20403
# Black                  2319
# Asian-Pac-Islander      718
# Amer-Indian-Eskimo      213
# Other                   189
# Name: race, dtype: int64
# Male      15926
# Female     7916
# Name: sex, dtype: int64
# United-States                 21316
# Mexico                          488
# ?                               430
# Philippines                     143
# Germany                         107
# Puerto-Rico                      97
# Canada                           89
# El-Salvador                      78
# India                            75
# Cuba                             68
# China                            62
# Jamaica                          60
# England                          59
# Dominican-Republic               58
# Italy                            57
# South                            54
# Japan                            48
# Haiti                            45
# Columbia                         44
# Vietnam                          43
# Poland                           42
# Guatemala                        42
# Taiwan                           32
# Portugal                         31
# Greece                           29
# Ecuador                          27
# Iran                             24
# Peru                             23
# Ireland                          23
# Nicaragua                        22
# France                           19
# Thailand                         16
# Cambodia                         14
# Outlying-US(Guam-USVI-etc)       11
# Hong                             11
# Trinadad&Tobago                  11
# Hungary                          11
# Laos                              9
# Yugoslavia                        9
# Honduras                          7
# Scotland                          7
# Holand-Netherlands                1
# Name: native.country, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in df.select_dtypes(include=['int', 'float']).columns:
    sns.histplot(df[col], kde=True)
    plt.show()

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-20-b874e109f562>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
